# %%
import pandas as pd

# %%
df =  pd.read_csv("C:/Users/Admin/Downloads/pizza_sales.csv")
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity  order_date order_time  \
# 0             1         1     hawaiian_m         1  01-01-2015   11:38:36
# 1             2         2  classic_dlx_m         1  01-01-2015   11:57:40
# 2             3         2  five_cheese_l         1  01-01-2015   11:57:40
# 3             4         2    ital_supr_l         1  01-01-2015   11:57:40
# 4             5         2     mexicana_m         1  01-01-2015   11:57:40
# ...         ...       ...            ...       ...         ...        ...
# 48615     48616     21348  ckn_alfredo_m         1  31-12-2015   21:23:10
# 48616     48617     21348  four_cheese_l         1  31-12-2015   21:23:10
# 48617     48618     21348   napolitana_s         1  31-12-2015   21:23:10
# 48618     48619     21349     mexicana_l         1  31-12-2015   22:09:54
# 48619     48620     21350      bbq_ckn_s         1  31-12-2015   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
import pandas as pd

# Assuming your dataset is loaded into a DataFrame called df
# df = pd.read_csv('pizza_sales_data.csv')  # Example

# Total Revenue
total_revenue = df['total_price'].sum()

# Total Orders
total_orders = df['order_id'].nunique()

# Total Pizzas Sold
total_pizzas_sold = df['quantity'].sum()

# Average Order Value (AOV)
average_order_value = total_revenue / total_orders

# Average Pizza per Order
average_pizza_per_order = total_pizzas_sold / total_orders

# Displaying the KPIs
print(f"Total Revenue: {total_revenue}")
print(f"Total Orders: {total_orders}")
print(f"Total Pizzas Sold: {total_pizzas_sold}")
print(f"Average Order Value: {average_order_value}")
print(f"Average Pizza per Order: {average_pizza_per_order}")
# Out:
# Total Revenue: 817860.05
# Total Orders: 21350
# Total Pizzas Sold: 49574
# Average Order Value: 38.30726229508197
# Average Pizza per Order: 2.321967213114754

# %%
import pandas as pd

# Load your dataset
# df = pd.read_csv('pizza_sales_data.csv')

# Convert 'order_date' to datetime format with the correct format
df['order_date'] = pd.to_datetime(df['order_date'], format='%d-%m-%Y')

# Create a new column 'day_of_week' from 'order_date'
df['day_of_week'] = df['order_date'].dt.day_name()

# Create a new column 'day_of_month' from 'order_date'
df['day_of_month'] = df['order_date'].dt.day

# Show the first few rows to verify the new columns
print(df[['order_date', 'day_of_week', 'day_of_month']].head())
# Out:
#   order_date day_of_week  day_of_month
# 0 2015-01-01    Thursday             1
# 1 2015-01-01    Thursday             1
# 2 2015-01-01    Thursday             1
# 3 2015-01-01    Thursday             1
# 4 2015-01-01    Thursday             1

# %%
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0             1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1             2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2             3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3             4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4             5         2     mexicana_m         1 2015-01-01   11:57:40
# ...         ...       ...            ...       ...        ...        ...
# 48615     48616     21348  ckn_alfredo_m         1 2015-12-31   21:23:10
# 48616     48617     21348  four_cheese_l         1 2015-12-31   21:23:10
# 48617     48618     21348   napolitana_s         1 2015-12-31   21:23:10
# 48618     48619     21349     mexicana_l         1 2015-12-31   22:09:54
# 48619     48620     21350      bbq_ckn_s         1 2015-12-31   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataset is loaded into a DataFrame called df
# df = pd.read_csv('pizza_sales_data.csv')

# Ensure 'order_date' is in datetime format and 'day_of_week' is created
df['order_date'] = pd.to_datetime(df['order_date'], format='%d-%m-%Y')
df['day_of_week'] = df['order_date'].dt.day_name()

# Group by 'day_of_week' and count the total number of orders
orders_by_day = df.groupby('day_of_week')['order_id'].nunique().sort_index()

# Define the order of days for the x-axis
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Plotting the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=orders_by_day.index, y=orders_by_day.values, order=day_order, palette='viridis')

# Customizing the chart
plt.title('Total Orders by Day of the Week', fontsize=16)
plt.xlabel('Day of the Week', fontsize=12)
plt.ylabel('Total Orders', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Assuming your dataset is loaded into a DataFrame called df
# df = pd.read_csv('pizza_sales_data.csv')

# Ensure 'order_date' is in datetime format
df['order_date'] = pd.to_datetime(df['order_date'], format='%d-%m-%Y')

# Extract month and year for grouping
df['year_month'] = df['order_date'].dt.to_period('M')

# Group by 'year_month' and count the total number of orders
monthly_orders = df.groupby('year_month')['order_id'].nunique()

# Convert 'year_month' to string for plotting
monthly_orders.index = monthly_orders.index.astype(str)

# Plotting the line chart
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_orders.index, y=monthly_orders.values, marker='o', color='blue')

# Customizing the chart
plt.title('Monthly Total Orders', fontsize=16)
plt.xlabel('Month-Year', fontsize=12)
plt.ylabel('Total Orders', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Assuming your dataset is loaded into a DataFrame called df
# df = pd.read_csv('pizza_sales_data.csv')

# Ensure 'total_price' is numeric
df['total_price'] = pd.to_numeric(df['total_price'], errors='coerce')

# Group by 'pizza_category' and sum the total sales
sales_by_category = df.groupby('pizza_category')['total_price'].sum()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sales_by_category, labels=sales_by_category.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(sales_by_category))))

# Customizing the chart
plt.title('Distribution of Sales Across Different Pizza Categories', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataset is loaded into a DataFrame called df
# df = pd.read_csv('pizza_sales_data.csv')

# Ensure 'total_price' is numeric
df['total_price'] = pd.to_numeric(df['total_price'], errors='coerce')

# Group by 'pizza_size' and sum the total sales
sales_by_size = df.groupby('pizza_size')['total_price'].sum()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(sales_by_size, labels=sales_by_size.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(sales_by_size))))

# Customizing the chart
plt.title('Distribution of Sales Across Different Pizza Sizes', fontsize=16)

# Show the plot
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Assuming your dataset is loaded into a DataFrame called df
# df = pd.read_csv('pizza_sales_data.csv')

# Group by 'pizza_category' and sum the total quantity sold
quantity_by_category = df.groupby('pizza_category')['quantity'].sum().sort_values(ascending=False)

# Define the number of categories
n_categories = len(quantity_by_category)

# Define the position of bars to create the funnel effect
positions = np.arange(n_categories)
widths = np.linspace(1, 0.5, n_categories)  # Funnel effect, decreasing width

# Plotting the funnel chart
plt.figure(figsize=(10, 8))
bars = plt.barh(positions, quantity_by_category, height=widths, color='skyblue', edgecolor='black')

# Customizing the chart
plt.title('Funnel Chart: Number of Pizzas Sold for Each Pizza Category', fontsize=16)
plt.xlabel('Number of Pizzas Sold', fontsize=12)
plt.yticks(positions, quantity_by_category.index)
plt.gca().invert_yaxis()  # Invert y-axis to have the largest value on top
plt.grid(axis='x')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Assuming your dataset is loaded into a DataFrame called df
# df = pd.read_csv('pizza_sales_data.csv')

# Group by 'pizza_name' and sum the total quantity sold
quantity_by_pizza = df.groupby('pizza_name')['quantity'].sum()

# Sort by quantity in descending order and get the top 5 pizzas
top_5_pizzas = quantity_by_pizza.sort_values(ascending=False).head(5)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=top_5_pizzas.index, y=top_5_pizzas.values, palette='viridis')

# Customizing the chart
plt.title('Top 5 Best-Selling Pizzas by Quantity Sold', fontsize=16)
plt.xlabel('Pizza Name', fontsize=12)
plt.ylabel('Total Quantity Sold', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataset is loaded into a DataFrame called df
# df = pd.read_csv('pizza_sales_data.csv')

# Ensure 'total_price' is numeric
df['total_price'] = pd.to_numeric(df['total_price'], errors='coerce')

# Group by 'pizza_name' and sum the total revenue
revenue_by_pizza = df.groupby('pizza_name')['total_price'].sum()

# Sort by revenue in descending order and get the top 5 pizzas
top_5_pizzas_by_revenue = revenue_by_pizza.sort_values(ascending=False).head(5)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=top_5_pizzas_by_revenue.index, y=top_5_pizzas_by_revenue.values, palette='viridis')

# Customizing the chart
plt.title('Top 5 Best-Selling Pizzas by Total Revenue', fontsize=16)
plt.xlabel('Pizza Name', fontsize=12)
plt.ylabel('Total Revenue', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your dataset is loaded into a DataFrame called df
# df = pd.read_csv('pizza_sales_data.csv')

# Group by 'pizza_name' and count the total number of orders
orders_by_pizza = df.groupby('pizza_name')['order_id'].count()

# Sort by orders in descending order and get the top 5 pizzas
top_5_pizzas_by_orders = orders_by_pizza.sort_values(ascending=False).head(5)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=top_5_pizzas_by_orders.index, y=top_5_pizzas_by_orders.values, palette='viridis')

# Customizing the chart
plt.title('Top 5 Best-Selling Pizzas by Total Orders', fontsize=16)
plt.xlabel('Pizza Name', fontsize=12)
plt.ylabel('Total Orders', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataset is loaded into a DataFrame called df
# df = pd.read_csv('pizza_sales_data.csv')

# Group by 'pizza_name' and sum the total quantity sold
quantity_by_pizza = df.groupby('pizza_name')['quantity'].sum().sort_values(ascending=True)

# Select the bottom 5 pizzas based on quantity
bottom_5_pizzas = quantity_by_pizza.head(5)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
plt.bar(bottom_5_pizzas.index, bottom_5_pizzas.values, color='salmon', edgecolor='black')

# Customizing the chart
plt.title('Bottom 5 Best-Selling Pizzas Based on Total Quantity', fontsize=16)
plt.xlabel('Pizza Name', fontsize=12)
plt.ylabel('Total Quantity Sold', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Ensure 'total_price' is numeric
df['total_price'] = pd.to_numeric(df['total_price'], errors='coerce')

# Group by 'pizza_name' and sum the total revenue
revenue_by_pizza = df.groupby('pizza_name')['total_price'].sum()

# Sort by revenue in ascending order and get the bottom 5 pizzas
bottom_5_pizzas_by_revenue = revenue_by_pizza.sort_values(ascending=True).head(5)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=bottom_5_pizzas_by_revenue.index, y=bottom_5_pizzas_by_revenue.values, palette='viridis')

# Customizing the chart
plt.title('Bottom 5 Best-Selling Pizzas by Total Revenue', fontsize=16)
plt.xlabel('Pizza Name', fontsize=12)
plt.ylabel('Total Revenue', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
orders_by_pizza = df.groupby('pizza_name')['order_id'].count()

# Sort by orders in ascending order and get the bottom 5 pizzas
bottom_5_pizzas_by_orders = orders_by_pizza.sort_values(ascending=True).head(5)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=bottom_5_pizzas_by_orders.index, y=bottom_5_pizzas_by_orders.values, palette='viridis')

# Customizing the chart
plt.title('Bottom 5 Best-Selling Pizzas by Total Orders', fontsize=16)
plt.xlabel('Pizza Name', fontsize=12)
plt.ylabel('Total Orders', fontsize=12)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %%
df
# Out:
#        pizza_id  order_id  pizza_name_id  quantity order_date order_time  \
# 0             1         1     hawaiian_m         1 2015-01-01   11:38:36
# 1             2         2  classic_dlx_m         1 2015-01-01   11:57:40
# 2             3         2  five_cheese_l         1 2015-01-01   11:57:40
# 3             4         2    ital_supr_l         1 2015-01-01   11:57:40
# 4             5         2     mexicana_m         1 2015-01-01   11:57:40
# ...         ...       ...            ...       ...        ...        ...
# 48615     48616     21348  ckn_alfredo_m         1 2015-12-31   21:23:10
# 48616     48617     21348  four_cheese_l         1 2015-12-31   21:23:10
# 48617     48618     21348   napolitana_s         1 2015-12-31   21:23:10
# 48618     48619     21349     mexicana_l         1 2015-12-31   22:09:54
# 48619     48620     21350      bbq_ckn_s         1 2015-12-31   23:02:05
#
#        unit_price  total_price pizza_size pizza_category  \
# ...
